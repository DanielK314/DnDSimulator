# %%
import numpy as np
import matplotlib.pyplot as plt

#This is the Score for the Deflect Missile Ability AI function

x = np.linspace(0,1,100)  #CHP/HP
y = [3/(np.exp((x0 - 0.2)*10) + 1) + 1 for x0 in x]
(3/(np.exp((x0 - 0.2)*10) + 1) + 1)
plt.plot(x,y)
